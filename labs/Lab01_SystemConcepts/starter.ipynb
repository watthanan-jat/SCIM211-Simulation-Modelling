# %% [markdown]
# # Lab 1: From Real System to Simulation Model
#
# ## Lab goals
#
# In this lab, you will review basic Python tools, describe a coffee shop as a simulation system, compare simulation worldviews, manually simulate a small deterministic queue, and then implement the queue calculation in Python.
#
# Complete the code TODOs and replace each **Write your answer here** prompt in the Markdown cells. This notebook contains both the practical work and the report.
#
# ## Student Information
#
# **Name:** Write your answer here
# **Student ID:** Write your answer here
# **Date:** Write your answer here

# %% [markdown]
# ## Part 0: Setup
#
# Run the imports below. If a library does not load, install requirements from the repository root with:
#
# ```bash
# pip install -r requirements.txt
# ```

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Part A: Python Warm-up for Simulation
#
# Use the given arrival and service-time data.

# %%
arrival = [1, 2, 5, 6, 10]
service = [3, 4, 2, 3, 2]

arrival, service

# %% [markdown]
# ### A1. Numerical summaries
#
# Compute mean, maximum, minimum, and cumulative sum for the service times.

# %%
# TODO: Compute the mean service time using np.mean
mean_service = None

# TODO: Compute the longest service time using np.max
longest_service = None

# TODO: Compute the shortest service time using np.min
shortest_service = None

# TODO: Compute the cumulative sum using np.cumsum
cumulative_service = None

mean_service, longest_service, shortest_service, cumulative_service

# %% [markdown]
# ### A1. Written answers
#
# 1. What is the mean service time? **Write your answer here.**
# 2. Which customer has the longest service time? **Write your answer here.**
# 3. What does cumulative sum mean here? **Write your answer here.**

# %% [markdown]
# ### A2. Create a DataFrame
#
# Create a table with one row per customer.

# %%
# TODO: Create a DataFrame with columns customer, arrival, and service
df = pd.DataFrame({
    "customer": [],
    "arrival": [],
    "service": []
})

df

# %% [markdown]
# ### A2. Written answers
#
# 1. Why is a DataFrame useful for simulation output? **Write your answer here.**
# 2. What does each row represent? **Write your answer here.**
# 3. What does each column represent? **Write your answer here.**

# %% [markdown]
# ### A3. Plot arrival times

# %%
# TODO: Plot customer number on the x-axis and arrival time on the y-axis

plt.xlabel("Customer")
plt.ylabel("Arrival time")
plt.title("Customer arrival times")
plt.show()

# %% [markdown]
# ### A3. Written answer
#
# What does the arrival-time plot tell you? **Write your answer here.**
#
# ## Part B: Coffee Shop as a System
#
# Scenario: A small coffee shop has one barista. Customers arrive, wait if the barista is busy, receive service, and leave.
#
# Replace each TODO in the table below with your answer.

# %% [markdown]
# | Concept | Coffee Shop Example |
# |---|---|
# | Entity | TODO |
# | Temporary entity | TODO |
# | Permanent entity | TODO |
# | Resource | TODO |
# | Activity | TODO |
# | Event 1 | TODO |
# | Event 2 | TODO |
# | State variable 1 | TODO |
# | State variable 2 | TODO |
# | Input randomness 1 | TODO |
# | Input randomness 2 | TODO |
# | Output measure 1 | TODO |
# | Output measure 2 | TODO |

# %% [markdown]
# ## Part C: Simulation Worldviews
#
# Replace each TODO in the comparison table below with your answer.

# %% [markdown]
# | Worldview | Main idea | Coffee-shop interpretation | Strength | Weakness |
# |---|---|---|---|---|
# | Event scheduling | TODO | TODO | TODO | TODO |
# | Process interaction | TODO | TODO | TODO | TODO |
# | Activity scanning | TODO | TODO | TODO | TODO |

# %% [markdown]
# ## Checkpoint 1: First Half (1 of 3 Points)
#
# Show your notebook to the TA after completing Parts A-C. To receive the first 1 point, your notebook must contain:
#
# 1. completed and executed Python warm-up code
# 2. written answers for Parts A1-A3
# 3. completed coffee-shop system-components table
# 4. completed simulation-worldviews comparison table
#
# The TA will record this checkpoint during the lab. Do not upload the notebook yet; continue with Parts D-F.

# %% [markdown]
# ## Part D: Manual Simulation
#
# Before coding, complete the manual simulation table below.
#
# | Customer | Arrival | Service starts | Service ends | Waiting time | Barista status after arrival |
# |---:|---:|---:|---:|---:|---|
# | 1 | 1 | TODO | TODO | TODO | TODO |
# | 2 | 2 | TODO | TODO | TODO | TODO |
# | 3 | 5 | TODO | TODO | TODO | TODO |
# | 4 | 6 | TODO | TODO | TODO | TODO |
# | 5 | 10 | TODO | TODO | TODO | TODO |
#
# **Average waiting time:** Write your answer here.
# **Longest-waiting customer:** Write your answer here.
# **When was the barista idle?** Write your answer here.
# **When was the queue longest?** Write your answer here.

# %%
customer = [1, 2, 3, 4, 5]
arrival = [1, 2, 5, 6, 10]
service = [3, 4, 2, 3, 2]

manual_df = pd.DataFrame({
    "customer": customer,
    "arrival": arrival,
    "service": service
})

manual_df

# %% [markdown]
# ## Part E: Python Implementation
#
# Complete the queue calculation. Your final DataFrame should contain:
#
# `customer`, `arrival`, `service`, `start`, `end`, `wait`

# %%
start_times = []
end_times = []
wait_times = []

for i in range(len(manual_df)):
    arrival_time = manual_df.loc[i, "arrival"]
    service_time = manual_df.loc[i, "service"]

    # TODO: Set the previous service end.
    previous_service_end = None

    # TODO: Calculate the service start.
    service_start = None

    # TODO: Calculate the service end.
    service_end = None

    # TODO: Calculate the waiting time.
    waiting_time = None

    # TODO: Append the three calculated values to their lists.

# TODO: Add the start, end, and wait columns to manual_df.

manual_df

# %%
# TODO: Compute average waiting time
average_wait = None

# TODO: Identify the customer with the longest waiting time
longest_waiting_customer = None

average_wait, longest_waiting_customer

# %%
# TODO: Plot waiting time by customer

plt.xlabel("Customer")
plt.ylabel("Waiting time")
plt.title("Waiting time by customer")
plt.show()

# %% [markdown]
# ## Part F: Investigation
#
# Change the first service time from 3 to 10 and repeat the simulation.
#
# Compare original and slow-first-customer average and longest waiting times. After running the code, complete the written responses near the end of this notebook.

# %%
slow_service = [10, 4, 2, 3, 2]

slow_df = pd.DataFrame({
    "customer": customer,
    "arrival": arrival,
    "service": slow_service
})

# TODO: Repeat the queue calculation for slow_df.
# You may reuse the same logic from Part E.

slow_df

# %%
# TODO: Create a comparison table with average waiting time and longest waiting time
comparison = pd.DataFrame({
    "Case": ["Original", "Slow first customer"],
    "Average waiting time": [None, None],
    "Longest waiting time": [None, None]
})

comparison

# %%
# TODO: Plot original and slow-first-customer waiting times on the same chart

plt.xlabel("Customer")
plt.ylabel("Waiting time")
plt.title("Effect of a slow first customer")
plt.legend()
plt.show()

# %% [markdown]
# ## Part F: Written responses
#
# **Original average waiting time:** Write your answer here.
# **Original longest waiting time:** Write your answer here.
# **Slow-first-customer average waiting time:** Write your answer here.
# **Slow-first-customer longest waiting time:** Write your answer here.
#
# 1. Why does one slow service affect later customers? **Write your answer here.**
# 2. What is a bottleneck? **Write your answer here.**
# 3. How might a manager reduce this problem? **Write your answer here.**
#
# ## Part G: Hand-drawn event-handling flowchart
#
# In computer science, a diagram that shows algorithm steps, decisions, and control flow is called a **flowchart**.
#
# On paper, draw an event-handling flowchart showing how the single-server coffee-shop system handles:
#
# 1. a customer arrival
# 2. a customer departure
# 3. the decision "Is the server idle?"
# 4. the decision "Is the queue empty?"
# 5. the possible actions: start service, join the queue, begin service for the next customer, or make the server idle
#
# Use rectangles for actions, diamonds for decisions, and labelled arrows to show the direction of control. Show the completed flowchart to the TA at Checkpoint 2. The paper flowchart does not need to be uploaded to Google Classroom.
#
# ## Reflection
#
# Write 150-200 words addressing these questions:
#
# 1. Which simulation worldview feels most natural to you and why?
# 2. Which worldview is probably best for coding a discrete-event simulation?
# 3. What was the most important state variable in today's model?
# 4. What assumption in today's model is unrealistic?
#
# **Write your reflection here.**
#
# ## AI Use Statement
#
# State whether AI tools were used, how they were used, and how you verified your work.
#
# **Write your AI use statement here.**
#
# ## Checkpoint 2: Final Submission
#
# 1. Show the completed Parts D-G, reflection, and AI use statement to the TA.
# 2. After the TA checkpoint, save it as `Lab01_StudentID.ipynb` (for example, `Lab01_6812345.ipynb`).
# 3. Restart the kernel and run all cells from top to bottom.
# 4. Check that there are no errors, then save the notebook.
# 5. Upload the notebook to the **Lab 01** assignment in Google Classroom before leaving the lab.
