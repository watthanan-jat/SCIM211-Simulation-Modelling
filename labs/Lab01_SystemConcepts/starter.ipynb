# %% [markdown]
# # Lab 1: From Real System to Simulation Model
#
# Complete the TODO cells. This notebook is a starter file, so it gives structure but not full solutions.

# %% [markdown]
# ## Part A: Python Warm-Up
#
# Review lists, arrays, DataFrames, and simple plots using coffee shop data.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# TODO: Create a Python list of five customer labels, such as C1, C2, ...
customers = []

# TODO: Print the list and its length

# %%
# TODO: Create numpy arrays for arrival times and service times
arrival_times = np.array([])
service_times = np.array([])

# TODO: Calculate and print a simple summary, such as total service time

# %%
# TODO: Create a pandas DataFrame with Customer, Arrival Time, and Service Time
df = pd.DataFrame()

# TODO: Display the DataFrame
df

# %%
# TODO: Create a simple plot of service time by customer
# Hint: use plt.plot(...) or df.plot(...)

plt.title("Service Time by Customer")
plt.xlabel("Customer")
plt.ylabel("Service Time")
plt.show()

# %% [markdown]
# ## Part B: Coffee Shop System Components
#
# Use the lab sheet to identify entities, resources, attributes, activities, events, and state variables.

# %% [markdown]
# TODO: Write short notes here before transferring your answer to `report_template.md`.
#
# - Entity:
# - Resource:
# - Attribute:
# - Activity:
# - Event:
# - State variable:

# %% [markdown]
# ## Part C: Simulation Worldviews
#
# TODO: Compare event scheduling, process interaction, and activity scanning in your own words.

# %% [markdown]
# | Worldview | Your short description | Coffee shop example |
# |---|---|---|
# | Event scheduling | TODO | TODO |
# | Process interaction | TODO | TODO |
# | Activity scanning | TODO | TODO |

# %% [markdown]
# ## Part D: Manual Deterministic Queue
#
# Complete the manual table in `report_template.md` before coding the result below.

# %%
# Given deterministic customer data
customers = [1, 2, 3, 4, 5]
arrival_times = np.array([0, 1, 2, 5, 6])
service_times = np.array([3, 2, 4, 2, 3])

queue_df = pd.DataFrame({
    "Customer": customers,
    "Arrival Time": arrival_times,
    "Service Time": service_times
})

queue_df

# %%
# TODO: Calculate service start, service end, and waiting time.
# Use a loop. Each customer depends on the previous service end time.

service_start = []
service_end = []
waiting_time = []

for i in range(len(queue_df)):
    arrival = queue_df.loc[i, "Arrival Time"]
    service = queue_df.loc[i, "Service Time"]
    
    # TODO: Set previous_end. For the first customer, there is no previous customer.
    # TODO: Calculate start = max(arrival, previous_end)
    # TODO: Calculate end = start + service
    # TODO: Calculate wait = start - arrival
    
    # TODO: Append start, end, and wait to their lists
    pass

# TODO: Add the three result columns to queue_df
queue_df

# %%
# TODO: Calculate the average waiting time
average_waiting_time = None
average_waiting_time

# %%
# TODO: Plot waiting time by customer

plt.title("Waiting Time by Customer")
plt.xlabel("Customer")
plt.ylabel("Waiting Time")
plt.show()

# %% [markdown]
# ## Part E: Long-Service Investigation
#
# Change the first customer's service time to a longer value, such as 8 minutes. Recalculate the queue measures and compare the waiting times.

# %%
# TODO: Copy the original data and change only the first customer's service time
long_service_df = queue_df[["Customer", "Arrival Time", "Service Time"]].copy()

# TODO: Set the first service time to a longer value

# TODO: Recalculate service start, service end, and waiting time
# You may reuse your loop from above, but adapt it for long_service_df.

long_service_df

# %%
# TODO: Compare original waiting times with long-service waiting times in one DataFrame
comparison_df = pd.DataFrame()

# TODO: Add a column showing the increase in waiting time
comparison_df

# %%
# TODO: Plot the original and long-service waiting times on the same chart

plt.title("Effect of Long First Service Time")
plt.xlabel("Customer")
plt.ylabel("Waiting Time")
plt.legend()
plt.show()

# %% [markdown]
# ## Checkpoint
#
# Before submitting, make sure you have:
#
# - Completed the TODO cells.
# - Completed `report_template.md`.
# - Answered the reflection questions.
# - Added an AI use statement.
