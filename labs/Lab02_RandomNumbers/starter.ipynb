# %% [markdown]
# # Lab 2: Random Numbers and Interarrival Times
#
# Complete the TODO cells. Do not paste a full solution from another source.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## LCG Warm-Up
#
# Implement a linear congruential generator and inspect the sequence.

# %%
# TODO: Choose LCG parameters a, c, m, seed, and n
a = None
c = None
m = None
seed = None
n = None

# TODO: Generate integer values X and uniform values U
X = []
U = []

# TODO: Store results in a DataFrame
lcg_df = pd.DataFrame()
lcg_df.head()

# %% [markdown]
# ## Histogram and Scatter Plot

# %%
# TODO: Plot a histogram of U values
plt.title("Histogram of LCG Uniform Values")
plt.xlabel("U")
plt.ylabel("Frequency")
plt.show()

# %%
# TODO: Plot U_i against U_{i+1}
plt.title("Scatter Plot of U_i vs U_{i+1}")
plt.xlabel("U_i")
plt.ylabel("U_{i+1}")
plt.show()

# %% [markdown]
# ## Exponential Interarrival Times
#
# Use inverse transform logic to convert uniforms into interarrival times.

# %%
# TODO: Choose an arrival rate lambda_rate
lambda_rate = None

# TODO: Convert U values to exponential interarrival times
interarrival_times = []

# TODO: Convert interarrival times to cumulative arrival times
arrival_times = []

arrival_df = pd.DataFrame()
arrival_df.head()

# %%
# TODO: Plot the simulated arrival times
plt.title("Simulated Customer Arrival Times")
plt.xlabel("Customer")
plt.ylabel("Arrival Time")
plt.show()

# %% [markdown]
# ## Investigation
#
# TODO: Try another seed and a deliberately small modulus. Record what changes in your report.

# %% [markdown]
# ## Checkpoint
#
# - Complete all TODO cells.
# - Complete `report_template.md`.
# - Include an AI use statement.
